# %% [markdown]
# class: 10
#
# train picture: 17943
#
# test picture: 4481
#
# TOP:-1

# %% [markdown]
# 60epoch
#
# 1:53:30
#
# 97.6889%
#
# 60epoch
#
# 1:43:16
#
# 98.5556%

# %%
import matplotlib.pyplot as plt
import sys
sys.path.append('../')
from utils import *

axis_loss, axis_acc = create_subplots(figsize=(18,10))
plot_log('alexnet_60epoch.log', axis_loss, axis_acc, batch_size=32, loss_legend='alexnet_60epoch')
plot_log('initial_alexnet_60epoch.log', axis_loss, axis_acc, batch_size=32, loss_legend='initial_alexnet_60epoch')
plt.show()

# %% [markdown]
# 10epoch
#
# 0:20:56
#
# 79.9778%
#
# 60epoch
#
# 2:06:18
#
# 90.1555%

# %%
axis_loss, axis_acc = create_subplots(figsize=(18,10))
plot_log_google('googlenet_10epoch.log', axis_loss, axis_acc, batch_size=32, loss_legend='googlenet_10epoch')
plot_log_google('googlenet_60epoch.log', axis_loss, axis_acc, batch_size=32, loss_legend='googlenet_60epoch')
plt.show()

# %% [markdown]
# 10epoch
#
# 0:34:15
#
# 80.2222%
#
# 60epoch
#
# 5:07:33
#
# 97.6444%

# %%
axis_loss, axis_acc = create_subplots(figsize=(18,10))
plot_log_google('googlenet_random_10epoch.log', axis_loss, axis_acc, batch_size=32, loss_legend='googlenet_random_10epoch')
plot_log_google('googlenet_random_60epoch.log', axis_loss, axis_acc, batch_size=32, loss_legend='googlenet_random_60epoch')
plt.show()

# %% [markdown]
# 50epoch
#
# 2:48:25
#
# 99.5778%

# %%
axis_loss, axis_acc = create_subplots(figsize=(18,10))
plot_log_google('initial_googlenet_random.log', axis_loss, axis_acc, batch_size=32, loss_legend='initial_googlenet_random')
plot_log_google('googlenet_10epoch.log', axis_loss, axis_acc, batch_size=32, loss_legend='googlenet_10epoch')
plot_log_google('googlenet_60epoch.log', axis_loss, axis_acc, batch_size=32, loss_legend='googlenet_60epoch')
plot_log_google('googlenet_random_10epoch.log', axis_loss, axis_acc, batch_size=32, loss_legend='googlenet_random_10epoch')
plot_log_google('googlenet_random_60epoch.log', axis_loss, axis_acc, batch_size=32, loss_legend='googlenet_random_60epoch')
plt.show()

# %% [markdown]
# 50
#
# 2:00:58
#
# 97.6445%
#
# 101
#
# 3:37:17
#
# 98.2667%
#
# 152
#
# 5:21:22
#
# 97.9556%

# %%
axis_loss, axis_acc = create_subplots(figsize=(18,10))
plot_log('resnet_50.log', axis_loss, axis_acc, batch_size=32, loss_legend='resnet50_15epoch')
plot_log('resnet_101.log', axis_loss, axis_acc, batch_size=32, loss_legend='resnet101_15epoch')
plot_log('resnet_152.log', axis_loss, axis_acc, batch_size=32, loss_legend='resnet152_15epoch')
plt.show()

# %%
axis_loss, axis_acc = create_subplots(figsize=(18,10))
plot_log('alexnet_60epoch.log', axis_loss, axis_acc, batch_size=32, loss_legend='alexnet-60epoch')
plot_log_google('initial_googlenet_random.log', axis_loss, axis_acc, batch_size=32, loss_legend='initial_googlenet_random')
plot_log_google('googlenet_10epoch.log', axis_loss, axis_acc, batch_size=32, loss_legend='googlenet_10epoch')
plot_log_google('googlenet_60epoch.log', axis_loss, axis_acc, batch_size=32, loss_legend='googlenet_60epoch')
plot_log_google('googlenet_random_10epoch.log', axis_loss, axis_acc, batch_size=32, loss_legend='googlenet_random_10epoch')
plot_log_google('googlenet_random_60epoch.log', axis_loss, axis_acc, batch_size=32, loss_legend='googlenet_random_60epoch')
plot_log('resnet_50.log', axis_loss, axis_acc, batch_size=32, loss_legend='resnet50_15epoch')
plot_log('resnet_101.log', axis_loss, axis_acc, batch_size=32, loss_legend='resnet101_15epoch')
plot_log('resnet_152.log', axis_loss, axis_acc, batch_size=32, loss_legend='resnet152_15epoch')
plt.show()
